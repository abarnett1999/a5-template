# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = "Amani Johnson-Singh-Barnett"
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Python for Data Science Bootcamp
# ## Assignment 5
#
# NOTE: This assignment has 4 problems.  Please write your code in the designated portion of the autograded answer cell.
#
# For this problem set, we'll be using the Jupyter notebook and nbgrader:
#
# ![](jupyter.png)
#
# ©2020 Luis Morales. All rights reserved.

# %% [markdown]
# ## Problem 1 (1 point)
#
# Write a function that reproduces the image with the annotations shown below
#
# Hint=Annotate the graph with text at (61,25), and create a black arrow.
#
#
# ![image.png](attachment:image.png)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image


fig, ax = plt.subplots()
ax.broken_barh([(110, 30), (150, 10)], (10, 9), facecolors='tab:blue')
ax.broken_barh([(10, 50), (100, 20), (130, 10)], (20, 9), facecolors=('tab:orange', 'tab:green', 'tab:red'))

ax.set_xlim([0, 200])
ax.set_ylim([5, 35])
ax.set_xlabel('seconds since start')
ax.set_yticks([15, 25])
ax.set_yticklabels(['Bill', 'Jim'])
ax.grid(True)
ax.annotate('race interrupted', (61, 25), 
           xytext=(0.8, 0.9), textcoords="axes fraction", arrowprops=dict(facecolor = 'black', shrink= 0.05), fontsize=16, horizontalalignment='right', verticalalignment='top')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
from PIL import Image
import io

def fig2img(fig):
    """Convert a Matplotlib figure to a PIL Image and return it"""
    from PIL import Image
    import io
    buf = io.BytesIO()
    fig.savefig(buf)
    buf.seek(0)
    img = Image.open(buf)
    return img

fig2=Image.open('testfigure.png')

assert fig2==fig2img(myfunction())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-e59254698592> in <module>
#      17 fig2=Image.open('testfigure.png')
#      18
# ---> 19 assert fig2==fig2img(myfunction())
#
# NameError: name 'myfunction' is not defined

# %% [markdown]
# ## Problem 2 (1 point)
#
# Write a function that reproduces the image shown below with different fill types.
#
# x is a list starting from 0.0 to 2 with a space of 0.01 between every number.
# y1 is list resulting from function sin(2pi * x)
# y2 is a list resulting from function 0.8*sin(4pi*x)
#
# ![image.png](attachment:image.png)

# %%
# YOUR CODE HERE
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image

def myfunction():

    # YOUR CODE HERE
    raise NotImplementedError()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0.0, 2, 0.01)
y1 = np.sin(2 * np.pi * x)
y2 = 0.8 * np.sin(4 * np.pi *x)

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True)

ax1.set_title('Fill between y1 and 0')
ax1.fill_between(x, 0, y1)



ax2.fill_between(x, y1, 1)
ax2.set_title('Fill between y1 and 1')


ax3.fill_between(x, y1, y2)
ax3.set_title('Fill between y1 and y2')
ax3.set_xlabel('x')

plt.axis('tight')
# Out:
# (-0.0995, 2.0895, -1.1, 1.1)

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
from PIL import Image
import io

def fig2img(fig):
    """Convert a Matplotlib figure to a PIL Image and return it"""
    from PIL import Image
    import io
    buf = io.BytesIO()
    fig.savefig(buf)
    buf.seek(0)
    img = Image.open(buf)
    return img

fig2=Image.open('testfigure2.png')

assert fig2==fig2img(myfunction())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-6-606596706ac9> in <module>
#      17 fig2=Image.open('testfigure2.png')
#      18
# ---> 19 assert fig2==fig2img(myfunction())
#
# <ipython-input-4-093e10c2c7ca> in myfunction()
#       7
#       8     # YOUR CODE HERE
# ----> 9     raise NotImplementedError()
#
# NotImplementedError:

# %% [markdown]
# ## Problem 3 (1 point)
#
# Write a function that reads file "ice_class_raw_data.csv", and loads its data to a dataframe.  Then create a pair-plot for all variables against each other for CAP=0 (blue color) and then superimposed for CAP=1 (red) matching figure below. You need to write annotation and explanation for each line of the code. Hint=Seaborn PairGrid
# ![image.png](attachment:image.png)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('seaborn-whitegrid')
import seaborn as sns

def myfunction():
    # YOUR CODE HERE
  
    
    raise NotImplementedError()

# %%
df = pd.read_csv("ice_class_raw_data.csv")
df
g = sns.PairGrid(df, hue="ces_y")
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)
g.add_legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import Image
from PIL import Image
import io

def fig2img(fig):
    """Convert a Matplotlib figure to a PIL Image and return it"""
    from PIL import Image
    import io
    buf = io.BytesIO()
    fig.savefig(buf)
    buf.seek(0)
    img = Image.open(buf)
    return img

fig2=Image.open('testfigure3.png')

assert fig2==fig2img(myfunction())
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-9-3504c1c977ba> in <module>
#      17 fig2=Image.open('testfigure3.png')
#      18
# ---> 19 assert fig2==fig2img(myfunction())
#
# <ipython-input-7-5da8a7391cc1> in myfunction()
#      10
#      11
# ---> 12     raise NotImplementedError()
#
# NotImplementedError:

# %% [markdown]
# ## Problem 4 (1 point)
#
# Create a function that simulates and return the estimated probability that six rolls of a fair six-sided die all give different numbers. You need to use computer to simulate N trials, and return the estimated probability as a float number. Hint: np.sort, np.diff, np.all

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()
import pandas as pd
import numpy as np
def myfunction(N):
    
    # YOUR CODE HERE
    raise NotImplementedError()

# %%
from math import factorial
res=myfunction(10000)
'''sorry, my testing code is hided this time!'''
